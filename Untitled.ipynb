# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from nltk import NaiveBayesClassifier
import nltk.classify.util
#import NaiveBayesClassifier

# %%
positive_vocab = [ 'awesome', 'outstanding', 'fantastic', 'terrific', 'good', 'nice', 'great', ':)' ]
negative_vocab = [ 'bad', 'terrible','useless', 'hate', ':(' ]
neutral_vocab = [ 'movie','the','sound','was','is','actors','did','know','words','not' ]

# %%
positive_vocab
# Out:
# ['awesome',
#  'outstanding',
#  'fantastic',
#  'terrific',
#  'good',
#  'nice',
#  'great',
#  ':)']

# %%
positive_vocab[0]
# Out:
# 'awesome'

# %%
postv=[]

# %%
i=0;
with open('positive-words.txt','r') as reader:
    t=reader.read()
    postv=t.split('\n')

# %%
type(postv)
# Out:
# list

# %%
negtv=[]
i=0
with open('negative-words.txt','r') as reader:
    t=reader.read()
    negtv=t.split('\n')

# %%
negtv
# Out:
# ['2-faced',
#  '2-faces',
#  'abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'achey',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
# ...

# %%
def word_feats(words):
    return dict([(word, True) for word in words])
negtv_fet=[(word_feats(neg), 'neg') for neg in negtv]
postv_fet=[(word_feats(pos), 'pos') for pos in postv]

# %%
negtv_fet
# Out:
# [({'2': True,
#    '-': True,
#    'f': True,
#    'a': True,
#    'c': True,
#    'e': True,
#    'd': True},
#   'neg'),
#  ({'2': True,
#    '-': True,
#    'f': True,
#    'a': True,
#    'c': True,
#    'e': True,
#    's': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'n': True,
#    'o': True,
#    'r': True,
#    'm': True,
#    'l': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'l': True,
#    'i': True,
#    's': True,
#    'h': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'm': True,
#    'i': True,
#    'n': True,
#    'l': True,
#    'e': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'm': True,
#    'i': True,
#    'n': True,
#    'l': True,
#    'y': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'm': True,
#    'i': True,
#    'n': True,
#    't': True,
#    'e': True},
#   'neg'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'm': True,
# ...

# %%
postv_fet
# Out:
# [({'a': True, '+': True}, 'pos'),
#  ({'a': True, 'b': True, 'o': True, 'u': True, 'n': True, 'd': True}, 'pos'),
#  ({'a': True,
#    'b': True,
#    'o': True,
#    'u': True,
#    'n': True,
#    'd': True,
#    's': True},
#   'pos'),
#  ({'a': True,
#    'b': True,
#    'u': True,
#    'n': True,
#    'd': True,
#    'c': True,
#    'e': True},
#   'pos'),
#  ({'a': True, 'b': True, 'u': True, 'n': True, 'd': True, 't': True}, 'pos'),
#  ({'a': True, 'c': True, 'e': True, 's': True, 'b': True, 'l': True}, 'pos'),
#  ({'a': True,
#    'c': True,
#    'e': True,
#    's': True,
#    'i': True,
#    'b': True,
#    'l': True},
#   'pos'),
#  ({'a': True, 'c': True, 'l': True, 'i': True, 'm': True}, 'pos'),
#  ({'a': True,
#    'c': True,
#    'l': True,
#    'i': True,
#    'm': True,
#    'e': True,
#    'd': True},
#   'pos'),
#  ({'a': True,
#    'c': True,
#    'l': True,
#    'm': True,
#    't': True,
#    'i': True,
#    'o': True,
#    'n': True},
#   'pos'),
# ...

# %%
train_set=postv_fet+negtv_fet

# %%
classifier=NavieBayesClassifier.train(train_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-e4356626ba25> in <module>
# ----> 1 classifier=NavieBayesClassifier.train(train_set)
#
# NameError: name 'NavieBayesClassifier' is not defined

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True
